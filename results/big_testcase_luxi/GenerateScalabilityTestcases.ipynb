# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from utils.testcase_creator import *
from optimization.sa.task_graph import PrecedenceGraph
import networkx as nx
import main
from pathlib import Path
from input.input_parameters import InputParameters, EMode, Timeouts
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def _repr_html_monkeypatches(dot):
    """
    Monkey-patching for ``pydot.Dot._repr_html_()` for rendering in jupyter cells.

    :param dot:
        a `pydot.Dot()` instance

    .. Note::
        Had to use ``_repr_html_()`` and not simply ``_repr_svg_()`` because
        (due to https://github.com/jupyterlab/jupyterlab/issues/7497)

    """
    pan_zoom_json = "{controlIconsEnabled: true, zoomScaleSensitivity: 0.4, fit: true}",
    element_styles = "width: 100%; height: 300px;",
    container_styles = ""
    svg_txt = dot._repr_svg_()
    html = f"""
        <div class="svg_container">
            <style>
                .svg_container {{
                    {container_styles}
                }}
                .svg_container SVG {{
                    {element_styles}
                }}
            </style>
            <script src="http://ariutta.github.io/svg-pan-zoom/dist/svg-pan-zoom.min.js"></script>
            <script type="text/javascript">
                var scriptTag = document.scripts[document.scripts.length - 1];
                var parentTag = scriptTag.parentNode;
                svg_el = parentTag.querySelector(".svg_container svg");
                svgPanZoom(svg_el, {pan_zoom_json});
            </script>
            {svg_txt}
        </</>
    """
    return html

# %%
from graphviz import Digraph
from input.model.nodes import switch
from input.model.task import ETaskType
from IPython.display import HTML

def visualize_topo(solution):
    testcase = solution.tc
    dot = Digraph(comment="base_topology", node_attr={"shape": "record"})
    for node in testcase.N.values():
        if isinstance(node, switch):
            dot.node(node.id, label=node.id + " (SW)", shape="circle")
        else:
            task_list = testcase.T_g[node.id]
            task_list = [task for task in task_list if task.type == ETaskType.NORMAL]
            # Create task rows
            task_rows = []

            for i in range(0, len(task_list), 3):
                task_row = "{"
                task_row += task_list[i].id if i < len(task_list) else ""
                task_row += "|" + task_list[i + 1].id if i + 1 < len(task_list) else ""
                task_row += "|" + task_list[i + 2].id if i + 2 < len(task_list) else ""
                task_row += "}"
                task_rows.append(task_row)

            # Assemble label
            layout_label = "{"
            layout_label += node.id + " (ES)"
            for task_row in task_rows:
                layout_label += "|" + task_row
            layout_label += "}"

            dot.node(node.id, label=layout_label)

    for link in testcase.L.values():
        dot.edge(link.src.id, link.dest.id)
        
    return HTML(_repr_html_monkeypatches(dot))

# %%
from IPython.display import Image, display

def visualize_DAGs(solution):
    testcase = solution.tc
    tg = PrecedenceGraph.from_applications(testcase)
    pdot = nx.drawing.nx_pydot.to_pydot(tg.DAG)
    return Image(pdot.create_png())

# %%
nr_sws = 500
nr_streams = 1000
tc_name = "luxi1000"

config = testcase_generation_config()

config.nr_sw = nr_sws
config.stream_max_rl = 1
config.nr_es = config.nr_sw * 3
config.connections_per_sw = 6
config.connections_per_es = 5

# 1500 Byte = 12us 
config.periods = [10000, 20000, 50000]


config.name = tc_name
path = create_testcase_without_tasks(config, nr_streams, Path(config.name + ".flex_network_description"), False)
#solution_object = main.run(InputParameters(EMode.VIEW, Timeouts(0, 0, 0), path, True, "", 8050, False, False, False))
# Out:
# Found possible graph. Is connected: True
# Create topology graph with 500 switches and 1500 end systems
# Created simple app for stream 0
# Created simple app for stream 1
# Created simple app for stream 2
# Created simple app for stream 3
# Created simple app for stream 4
# Created simple app for stream 5
# Created simple app for stream 6
# Created simple app for stream 7
# Created simple app for stream 8
# Created simple app for stream 9
# Created simple app for stream 10
# Created simple app for stream 11
# Created simple app for stream 12
# Created simple app for stream 13
# Created simple app for stream 14
# Created simple app for stream 15
# Created simple app for stream 16
# Created simple app for stream 17
# Created simple app for stream 18
# Created simple app for stream 19
# Created simple app for stream 20
# Created simple app for stream 21
# Created simple app for stream 22
# Created simple app for stream 23
# Created simple app for stream 24
# Created simple app for stream 25
# Created simple app for stream 26
# Created simple app for stream 27
# Created simple app for stream 28
# Created simple app for stream 29
# Created simple app for stream 30
# Created simple app for stream 31
# Created simple app for stream 32
# Created simple app for stream 33
# Created simple app for stream 34
# Created simple app for stream 35
# Created simple app for stream 36
# Created simple app for stream 37
# Created simple app for stream 38
# Created simple app for stream 39
# Created simple app for stream 40
# Created simple app for stream 41
# Created simple app for stream 42
# Created simple app for stream 43
# Created simple app for stream 44
# Created simple app for stream 45
# Created simple app for stream 46
# Created simple app for stream 47
# Created simple app for stream 48
# Created simple app for stream 49
# Created simple app for stream 50
# Created simple app for stream 51
# Created simple app for stream 52
# Created simple app for stream 53
# Created simple app for stream 54
# Created simple app for stream 55
# Created simple app for stream 56
# Created simple app for stream 57
# Created simple app for stream 58
# Created simple app for stream 59
# Created simple app for stream 60
# Created simple app for stream 61
# Created simple app for stream 62
# Created simple app for stream 63
# Created simple app for stream 64
# Created simple app for stream 65
# Created simple app for stream 66
# Created simple app for stream 67
# Created simple app for stream 68
# Created simple app for stream 69
# Created simple app for stream 70
# Created simple app for stream 71
# Created simple app for stream 72
# Created simple app for stream 73
# Created simple app for stream 74
# Created simple app for stream 75
# Created simple app for stream 76
# Created simple app for stream 77
# Created simple app for stream 78
# Created simple app for stream 79
# Created simple app for stream 80
# Created simple app for stream 81
# Created simple app for stream 82
# Created simple app for stream 83
# Created simple app for stream 84
# Created simple app for stream 85
# Created simple app for stream 86
# Created simple app for stream 87
# Created simple app for stream 88
# Created simple app for stream 89
# Created simple app for stream 90
# Created simple app for stream 91
# Created simple app for stream 92
# Created simple app for stream 93
# Created simple app for stream 94
# Created simple app for stream 95
# Created simple app for stream 96
# Created simple app for stream 97
# Created simple app for stream 98
# Created simple app for stream 99
# Created simple app for stream 100
# Created simple app for stream 101
# Created simple app for stream 102
# Created simple app for stream 103
# Created simple app for stream 104
# Created simple app for stream 105
# Created simple app for stream 106
# Created simple app for stream 107
# Created simple app for stream 108
# Created simple app for stream 109
# Created simple app for stream 110
# Created simple app for stream 111
# Created simple app for stream 112
# Created simple app for stream 113
# Created simple app for stream 114
# Created simple app for stream 115
# Created simple app for stream 116
# Created simple app for stream 117
# Created simple app for stream 118
# Created simple app for stream 119
# Created simple app for stream 120
# Created simple app for stream 121
# Created simple app for stream 122
# Created simple app for stream 123
# Created simple app for stream 124
# Created simple app for stream 125
# Created simple app for stream 126
# Created simple app for stream 127
# Created simple app for stream 128
# Created simple app for stream 129
# Created simple app for stream 130
# Created simple app for stream 131
# Created simple app for stream 132
# Created simple app for stream 133
# Created simple app for stream 134
# Created simple app for stream 135
# Created simple app for stream 136
# Created simple app for stream 137
# Created simple app for stream 138
# Created simple app for stream 139
# Created simple app for stream 140
# Created simple app for stream 141
# Created simple app for stream 142
# Created simple app for stream 143
# Created simple app for stream 144
# Created simple app for stream 145
# Created simple app for stream 146
# Created simple app for stream 147
# Created simple app for stream 148
# Created simple app for stream 149
# Created simple app for stream 150
# Created simple app for stream 151
# Created simple app for stream 152
# Created simple app for stream 153
# Created simple app for stream 154
# Created simple app for stream 155
# Created simple app for stream 156
# Created simple app for stream 157
# Created simple app for stream 158
# Created simple app for stream 159
# Created simple app for stream 160
# Created simple app for stream 161
# Created simple app for stream 162
# Created simple app for stream 163
# Created simple app for stream 164
# Created simple app for stream 165
# Created simple app for stream 166
# Created simple app for stream 167
# Created simple app for stream 168
# Created simple app for stream 169
# Created simple app for stream 170
# Created simple app for stream 171
# Created simple app for stream 172
# Created simple app for stream 173
# Created simple app for stream 174
# Created simple app for stream 175
# Created simple app for stream 176
# Created simple app for stream 177
# Created simple app for stream 178
# Created simple app for stream 179
# Created simple app for stream 180
# Created simple app for stream 181
# Created simple app for stream 182
# Created simple app for stream 183
# Created simple app for stream 184
# Created simple app for stream 185
# Created simple app for stream 186
# Created simple app for stream 187
# Created simple app for stream 188
# Created simple app for stream 189
# Created simple app for stream 190
# Created simple app for stream 191
# Created simple app for stream 192
# Created simple app for stream 193
# Created simple app for stream 194
# Created simple app for stream 195
# Created simple app for stream 196
# Created simple app for stream 197
# Created simple app for stream 198
# Created simple app for stream 199
# Created simple app for stream 200
# Created simple app for stream 201
# Created simple app for stream 202
# Created simple app for stream 203
# Created simple app for stream 204
# Created simple app for stream 205
# Created simple app for stream 206
# Created simple app for stream 207
# Created simple app for stream 208
# Created simple app for stream 209
# Created simple app for stream 210
# Created simple app for stream 211
# Created simple app for stream 212
# Created simple app for stream 213
# Created simple app for stream 214
# Created simple app for stream 215
# Created simple app for stream 216
# Created simple app for stream 217
# Created simple app for stream 218
# Created simple app for stream 219
# Created simple app for stream 220
# Created simple app for stream 221
# Created simple app for stream 222
# Created simple app for stream 223
# Created simple app for stream 224
# Created simple app for stream 225
# Created simple app for stream 226
# Created simple app for stream 227
# Created simple app for stream 228
# Created simple app for stream 229
# Created simple app for stream 230
# Created simple app for stream 231
# Created simple app for stream 232
# Created simple app for stream 233
# Created simple app for stream 234
# Created simple app for stream 235
# Created simple app for stream 236
# Created simple app for stream 237
# Created simple app for stream 238
# Created simple app for stream 239
# Created simple app for stream 240
# Created simple app for stream 241
# Created simple app for stream 242
# Created simple app for stream 243
# Created simple app for stream 244
# Created simple app for stream 245
# Created simple app for stream 246
# Created simple app for stream 247
# Created simple app for stream 248
# Created simple app for stream 249
# Created simple app for stream 250
# Created simple app for stream 251
# Created simple app for stream 252
# Created simple app for stream 253
# Created simple app for stream 254
# Created simple app for stream 255
# Created simple app for stream 256
# Created simple app for stream 257
# Created simple app for stream 258
# Created simple app for stream 259
# Created simple app for stream 260
# Created simple app for stream 261
# Created simple app for stream 262
# Created simple app for stream 263
# Created simple app for stream 264
# Created simple app for stream 265
# Created simple app for stream 266
# Created simple app for stream 267
# Created simple app for stream 268
# Created simple app for stream 269
# Created simple app for stream 270
# Created simple app for stream 271
# Created simple app for stream 272
# Created simple app for stream 273
# Created simple app for stream 274
# Created simple app for stream 275
# Created simple app for stream 276
# Created simple app for stream 277
# Created simple app for stream 278
# Created simple app for stream 279
# Created simple app for stream 280
# Created simple app for stream 281
# Created simple app for stream 282
# Created simple app for stream 283
# Created simple app for stream 284
# Created simple app for stream 285
# Created simple app for stream 286
# Created simple app for stream 287
# Created simple app for stream 288
# Created simple app for stream 289
# Created simple app for stream 290
# Created simple app for stream 291
# Created simple app for stream 292
# Created simple app for stream 293
# Created simple app for stream 294
# Created simple app for stream 295
# Created simple app for stream 296
# Created simple app for stream 297
# Created simple app for stream 298
# Created simple app for stream 299
# Created simple app for stream 300
# Created simple app for stream 301
# Created simple app for stream 302
# Created simple app for stream 303
# Created simple app for stream 304
# Created simple app for stream 305
# Created simple app for stream 306
# Created simple app for stream 307
# Created simple app for stream 308
# Created simple app for stream 309
# Created simple app for stream 310
# Created simple app for stream 311
# Created simple app for stream 312
# Created simple app for stream 313
# Created simple app for stream 314
# Created simple app for stream 315
# Created simple app for stream 316
# Created simple app for stream 317
# Created simple app for stream 318
# Created simple app for stream 319
# Created simple app for stream 320
# Created simple app for stream 321
# Created simple app for stream 322
# Created simple app for stream 323
# Created simple app for stream 324
# Created simple app for stream 325
# Created simple app for stream 326
# Created simple app for stream 327
# Created simple app for stream 328
# Created simple app for stream 329
# Created simple app for stream 330
# Created simple app for stream 331
# Created simple app for stream 332
# Created simple app for stream 333
# Created simple app for stream 334
# Created simple app for stream 335
# Created simple app for stream 336
# Created simple app for stream 337
# Created simple app for stream 338
# Created simple app for stream 339
# Created simple app for stream 340
# Created simple app for stream 341
# Created simple app for stream 342
# Created simple app for stream 343
# Created simple app for stream 344
# Created simple app for stream 345
# Created simple app for stream 346
# Created simple app for stream 347
# Created simple app for stream 348
# Created simple app for stream 349
# Created simple app for stream 350
# Created simple app for stream 351
# Created simple app for stream 352
# Created simple app for stream 353
# Created simple app for stream 354
# Created simple app for stream 355
# Created simple app for stream 356
# Created simple app for stream 357
# Created simple app for stream 358
# Created simple app for stream 359
# Created simple app for stream 360
# Created simple app for stream 361
# Created simple app for stream 362
# Created simple app for stream 363
# Created simple app for stream 364
# Created simple app for stream 365
# Created simple app for stream 366
# Created simple app for stream 367
# Created simple app for stream 368
# Created simple app for stream 369
# Created simple app for stream 370
# Created simple app for stream 371
# Created simple app for stream 372
# Created simple app for stream 373
# Created simple app for stream 374
# Created simple app for stream 375
# Created simple app for stream 376
# Created simple app for stream 377
# Created simple app for stream 378
# Created simple app for stream 379
# Created simple app for stream 380
# Created simple app for stream 381
# Created simple app for stream 382
# Created simple app for stream 383
# Created simple app for stream 384
# Created simple app for stream 385
# Created simple app for stream 386
# Created simple app for stream 387
# Created simple app for stream 388
# Created simple app for stream 389
# Created simple app for stream 390
# Created simple app for stream 391
# Created simple app for stream 392
# Created simple app for stream 393
# Created simple app for stream 394
# Created simple app for stream 395
# Created simple app for stream 396
# Created simple app for stream 397
# Created simple app for stream 398
# Created simple app for stream 399
# Created simple app for stream 400
# Created simple app for stream 401
# Created simple app for stream 402
# Created simple app for stream 403
# Created simple app for stream 404
# Created simple app for stream 405
# Created simple app for stream 406
# Created simple app for stream 407
# Created simple app for stream 408
# Created simple app for stream 409
# Created simple app for stream 410
# Created simple app for stream 411
# Created simple app for stream 412
# Created simple app for stream 413
# Created simple app for stream 414
# Created simple app for stream 415
# Created simple app for stream 416
# Created simple app for stream 417
# Created simple app for stream 418
# Created simple app for stream 419
# Created simple app for stream 420
# Created simple app for stream 421
# Created simple app for stream 422
# Created simple app for stream 423
# Created simple app for stream 424
# Created simple app for stream 425
# Created simple app for stream 426
# Created simple app for stream 427
# Created simple app for stream 428
# Created simple app for stream 429
# Created simple app for stream 430
# Created simple app for stream 431
# Created simple app for stream 432
# Created simple app for stream 433
# Created simple app for stream 434
# Created simple app for stream 435
# Created simple app for stream 436
# Created simple app for stream 437
# Created simple app for stream 438
# Created simple app for stream 439
# Created simple app for stream 440
# Created simple app for stream 441
# Created simple app for stream 442
# Created simple app for stream 443
# Created simple app for stream 444
# Created simple app for stream 445
# Created simple app for stream 446
# Created simple app for stream 447
# Created simple app for stream 448
# Created simple app for stream 449
# Created simple app for stream 450
# Created simple app for stream 451
# Created simple app for stream 452
# Created simple app for stream 453
# Created simple app for stream 454
# Created simple app for stream 455
# Created simple app for stream 456
# Created simple app for stream 457
# Created simple app for stream 458
# Created simple app for stream 459
# Created simple app for stream 460
# Created simple app for stream 461
# Created simple app for stream 462
# Created simple app for stream 463
# Created simple app for stream 464
# Created simple app for stream 465
# Created simple app for stream 466
# Created simple app for stream 467
# Created simple app for stream 468
# Created simple app for stream 469
# Created simple app for stream 470
# Created simple app for stream 471
# Created simple app for stream 472
# Created simple app for stream 473
# Created simple app for stream 474
# Created simple app for stream 475
# Created simple app for stream 476
# Created simple app for stream 477
# Created simple app for stream 478
# Created simple app for stream 479
# Created simple app for stream 480
# Created simple app for stream 481
# Created simple app for stream 482
# Created simple app for stream 483
# Created simple app for stream 484
# Created simple app for stream 485
# Created simple app for stream 486
# Created simple app for stream 487
# Created simple app for stream 488
# Created simple app for stream 489
# Created simple app for stream 490
# Created simple app for stream 491
# Created simple app for stream 492
# Created simple app for stream 493
# Created simple app for stream 494
# Created simple app for stream 495
# Created simple app for stream 496
# Created simple app for stream 497
# Created simple app for stream 498
# Created simple app for stream 499
# Created simple app for stream 500
# Created simple app for stream 501
# Created simple app for stream 502
# Created simple app for stream 503
# Created simple app for stream 504
# Created simple app for stream 505
# Created simple app for stream 506
# Created simple app for stream 507
# Created simple app for stream 508
# Created simple app for stream 509
# Created simple app for stream 510
# Created simple app for stream 511
# Created simple app for stream 512
# Created simple app for stream 513
# Created simple app for stream 514
# Created simple app for stream 515
# Created simple app for stream 516
# Created simple app for stream 517
# Created simple app for stream 518
# Created simple app for stream 519
# Created simple app for stream 520
# Created simple app for stream 521
# Created simple app for stream 522
# Created simple app for stream 523
# Created simple app for stream 524
# Created simple app for stream 525
# Created simple app for stream 526
# Created simple app for stream 527
# Created simple app for stream 528
# Created simple app for stream 529
# Created simple app for stream 530
# Created simple app for stream 531
# Created simple app for stream 532
# Created simple app for stream 533
# Created simple app for stream 534
# Created simple app for stream 535
# Created simple app for stream 536
# Created simple app for stream 537
# Created simple app for stream 538
# Created simple app for stream 539
# Created simple app for stream 540
# Created simple app for stream 541
# Created simple app for stream 542
# Created simple app for stream 543
# Created simple app for stream 544
# Created simple app for stream 545
# Created simple app for stream 546
# Created simple app for stream 547
# Created simple app for stream 548
# Created simple app for stream 549
# Created simple app for stream 550
# Created simple app for stream 551
# Created simple app for stream 552
# Created simple app for stream 553
# Created simple app for stream 554
# Created simple app for stream 555
# Created simple app for stream 556
# Created simple app for stream 557
# Created simple app for stream 558
# Created simple app for stream 559
# Created simple app for stream 560
# Created simple app for stream 561
# Created simple app for stream 562
# Created simple app for stream 563
# Created simple app for stream 564
# Created simple app for stream 565
# Created simple app for stream 566
# Created simple app for stream 567
# Created simple app for stream 568
# Created simple app for stream 569
# Created simple app for stream 570
# Created simple app for stream 571
# Created simple app for stream 572
# Created simple app for stream 573
# Created simple app for stream 574
# Created simple app for stream 575
# Created simple app for stream 576
# Created simple app for stream 577
# Created simple app for stream 578
# Created simple app for stream 579
# Created simple app for stream 580
# Created simple app for stream 581
# Created simple app for stream 582
# Created simple app for stream 583
# Created simple app for stream 584
# Created simple app for stream 585
# Created simple app for stream 586
# Created simple app for stream 587
# Created simple app for stream 588
# Created simple app for stream 589
# Created simple app for stream 590
# Created simple app for stream 591
# Created simple app for stream 592
# Created simple app for stream 593
# Created simple app for stream 594
# Created simple app for stream 595
# Created simple app for stream 596
# Created simple app for stream 597
# Created simple app for stream 598
# Created simple app for stream 599
# Created simple app for stream 600
# Created simple app for stream 601
# Created simple app for stream 602
# Created simple app for stream 603
# Created simple app for stream 604
# Created simple app for stream 605
# Created simple app for stream 606
# Created simple app for stream 607
# Created simple app for stream 608
# Created simple app for stream 609
# Created simple app for stream 610
# Created simple app for stream 611
# Created simple app for stream 612
# Created simple app for stream 613
# Created simple app for stream 614
# Created simple app for stream 615
# Created simple app for stream 616
# Created simple app for stream 617
# Created simple app for stream 618
# Created simple app for stream 619
# Created simple app for stream 620
# Created simple app for stream 621
# Created simple app for stream 622
# Created simple app for stream 623
# Created simple app for stream 624
# Created simple app for stream 625
# Created simple app for stream 626
# Created simple app for stream 627
# Created simple app for stream 628
# Created simple app for stream 629
# Created simple app for stream 630
# Created simple app for stream 631
# Created simple app for stream 632
# Created simple app for stream 633
# Created simple app for stream 634
# Created simple app for stream 635
# Created simple app for stream 636
# Created simple app for stream 637
# Created simple app for stream 638
# Created simple app for stream 639
# Created simple app for stream 640
# Created simple app for stream 641
# Created simple app for stream 642
# Created simple app for stream 643
# Created simple app for stream 644
# Created simple app for stream 645
# Created simple app for stream 646
# Created simple app for stream 647
# Created simple app for stream 648
# Created simple app for stream 649
# Created simple app for stream 650
# Created simple app for stream 651
# Created simple app for stream 652
# Created simple app for stream 653
# Created simple app for stream 654
# Created simple app for stream 655
# Created simple app for stream 656
# Created simple app for stream 657
# Created simple app for stream 658
# Created simple app for stream 659
# Created simple app for stream 660
# Created simple app for stream 661
# Created simple app for stream 662
# Created simple app for stream 663
# Created simple app for stream 664
# Created simple app for stream 665
# Created simple app for stream 666
# Created simple app for stream 667
# Created simple app for stream 668
# Created simple app for stream 669
# Created simple app for stream 670
# Created simple app for stream 671
# Created simple app for stream 672
# Created simple app for stream 673
# Created simple app for stream 674
# Created simple app for stream 675
# Created simple app for stream 676
# Created simple app for stream 677
# Created simple app for stream 678
# Created simple app for stream 679
# Created simple app for stream 680
# Created simple app for stream 681
# Created simple app for stream 682
# Created simple app for stream 683
# Created simple app for stream 684
# Created simple app for stream 685
# Created simple app for stream 686
# Created simple app for stream 687
# Created simple app for stream 688
# Created simple app for stream 689
# Created simple app for stream 690
# Created simple app for stream 691
# Created simple app for stream 692
# Created simple app for stream 693
# Created simple app for stream 694
# Created simple app for stream 695
# Created simple app for stream 696
# Created simple app for stream 697
# Created simple app for stream 698
# Created simple app for stream 699
# Created simple app for stream 700
# Created simple app for stream 701
# Created simple app for stream 702
# Created simple app for stream 703
# Created simple app for stream 704
# Created simple app for stream 705
# Created simple app for stream 706
# Created simple app for stream 707
# Created simple app for stream 708
# Created simple app for stream 709
# Created simple app for stream 710
# Created simple app for stream 711
# Created simple app for stream 712
# Created simple app for stream 713
# Created simple app for stream 714
# Created simple app for stream 715
# Created simple app for stream 716
# Created simple app for stream 717
# Created simple app for stream 718
# Created simple app for stream 719
# Created simple app for stream 720
# Created simple app for stream 721
# Created simple app for stream 722
# Created simple app for stream 723
# Created simple app for stream 724
# Created simple app for stream 725
# Created simple app for stream 726
# Created simple app for stream 727
# Created simple app for stream 728
# Created simple app for stream 729
# Created simple app for stream 730
# Created simple app for stream 731
# Created simple app for stream 732
# Created simple app for stream 733
# Created simple app for stream 734
# Created simple app for stream 735
# Created simple app for stream 736
# Created simple app for stream 737
# Created simple app for stream 738
# Created simple app for stream 739
# Created simple app for stream 740
# Created simple app for stream 741
# Created simple app for stream 742
# Created simple app for stream 743
# Created simple app for stream 744
# Created simple app for stream 745
# Created simple app for stream 746
# Created simple app for stream 747
# Created simple app for stream 748
# Created simple app for stream 749
# Created simple app for stream 750
# Created simple app for stream 751
# Created simple app for stream 752
# Created simple app for stream 753
# Created simple app for stream 754
# Created simple app for stream 755
# Created simple app for stream 756
# Created simple app for stream 757
# Created simple app for stream 758
# Created simple app for stream 759
# Created simple app for stream 760
# Created simple app for stream 761
# Created simple app for stream 762
# Created simple app for stream 763
# Created simple app for stream 764
# Created simple app for stream 765
# Created simple app for stream 766
# Created simple app for stream 767
# Created simple app for stream 768
# Created simple app for stream 769
# Created simple app for stream 770
# Created simple app for stream 771
# Created simple app for stream 772
# Created simple app for stream 773
# Created simple app for stream 774
# Created simple app for stream 775
# Created simple app for stream 776
# Created simple app for stream 777
# Created simple app for stream 778
# Created simple app for stream 779
# Created simple app for stream 780
# Created simple app for stream 781
# Created simple app for stream 782
# Created simple app for stream 783
# Created simple app for stream 784
# Created simple app for stream 785
# Created simple app for stream 786
# Created simple app for stream 787
# Created simple app for stream 788
# Created simple app for stream 789
# Created simple app for stream 790
# Created simple app for stream 791
# Created simple app for stream 792
# Created simple app for stream 793
# Created simple app for stream 794
# Created simple app for stream 795
# Created simple app for stream 796
# Created simple app for stream 797
# Created simple app for stream 798
# Created simple app for stream 799
# Created simple app for stream 800
# Created simple app for stream 801
# Created simple app for stream 802
# Created simple app for stream 803
# Created simple app for stream 804
# Created simple app for stream 805
# Created simple app for stream 806
# Created simple app for stream 807
# Created simple app for stream 808
# Created simple app for stream 809
# Created simple app for stream 810
# Created simple app for stream 811
# Created simple app for stream 812
# Created simple app for stream 813
# Created simple app for stream 814
# Created simple app for stream 815
# Created simple app for stream 816
# Created simple app for stream 817
# Created simple app for stream 818
# Created simple app for stream 819
# Created simple app for stream 820
# Created simple app for stream 821
# Created simple app for stream 822
# Created simple app for stream 823
# Created simple app for stream 824
# Created simple app for stream 825
# Created simple app for stream 826
# Created simple app for stream 827
# Created simple app for stream 828
# Created simple app for stream 829
# Created simple app for stream 830
# Created simple app for stream 831
# Created simple app for stream 832
# Created simple app for stream 833
# Created simple app for stream 834
# Created simple app for stream 835
# Created simple app for stream 836
# Created simple app for stream 837
# Created simple app for stream 838
# Created simple app for stream 839
# Created simple app for stream 840
# Created simple app for stream 841
# Created simple app for stream 842
# Created simple app for stream 843
# Created simple app for stream 844
# Created simple app for stream 845
# Created simple app for stream 846
# Created simple app for stream 847
# Created simple app for stream 848
# Created simple app for stream 849
# Created simple app for stream 850
# Created simple app for stream 851
# Created simple app for stream 852
# Created simple app for stream 853
# Created simple app for stream 854
# Created simple app for stream 855
# Created simple app for stream 856
# Created simple app for stream 857
# Created simple app for stream 858
# Created simple app for stream 859
# Created simple app for stream 860
# Created simple app for stream 861
# Created simple app for stream 862
# Created simple app for stream 863
# Created simple app for stream 864
# Created simple app for stream 865
# Created simple app for stream 866
# Created simple app for stream 867
# Created simple app for stream 868
# Created simple app for stream 869
# Created simple app for stream 870
# Created simple app for stream 871
# Created simple app for stream 872
# Created simple app for stream 873
# Created simple app for stream 874
# Created simple app for stream 875
# Created simple app for stream 876
# Created simple app for stream 877
# Created simple app for stream 878
# Created simple app for stream 879
# Created simple app for stream 880
# Created simple app for stream 881
# Created simple app for stream 882
# Created simple app for stream 883
# Created simple app for stream 884
# Created simple app for stream 885
# Created simple app for stream 886
# Created simple app for stream 887
# Created simple app for stream 888
# Created simple app for stream 889
# Created simple app for stream 890
# Created simple app for stream 891
# Created simple app for stream 892
# Created simple app for stream 893
# Created simple app for stream 894
# Created simple app for stream 895
# Created simple app for stream 896
# Created simple app for stream 897
# Created simple app for stream 898
# Created simple app for stream 899
# Created simple app for stream 900
# Created simple app for stream 901
# Created simple app for stream 902
# Created simple app for stream 903
# Created simple app for stream 904
# Created simple app for stream 905
# Created simple app for stream 906
# Created simple app for stream 907
# Created simple app for stream 908
# Created simple app for stream 909
# Created simple app for stream 910
# Created simple app for stream 911
# Created simple app for stream 912
# Created simple app for stream 913
# Created simple app for stream 914
# Created simple app for stream 915
# Created simple app for stream 916
# Created simple app for stream 917
# Created simple app for stream 918
# Created simple app for stream 919
# Created simple app for stream 920
# Created simple app for stream 921
# Created simple app for stream 922
# Created simple app for stream 923
# Created simple app for stream 924
# Created simple app for stream 925
# Created simple app for stream 926
# Created simple app for stream 927
# Created simple app for stream 928
# Created simple app for stream 929
# Created simple app for stream 930
# Created simple app for stream 931
# Created simple app for stream 932
# Created simple app for stream 933
# Created simple app for stream 934
# Created simple app for stream 935
# Created simple app for stream 936
# Created simple app for stream 937
# Created simple app for stream 938
# Created simple app for stream 939
# Created simple app for stream 940
# Created simple app for stream 941
# Created simple app for stream 942
# Created simple app for stream 943
# Created simple app for stream 944
# Created simple app for stream 945
# Created simple app for stream 946
# Created simple app for stream 947
# Created simple app for stream 948
# Created simple app for stream 949
# Created simple app for stream 950
# Created simple app for stream 951
# Created simple app for stream 952
# Created simple app for stream 953
# Created simple app for stream 954
# Created simple app for stream 955
# Created simple app for stream 956
# Created simple app for stream 957
# Created simple app for stream 958
# Created simple app for stream 959
# Created simple app for stream 960
# Created simple app for stream 961
# Created simple app for stream 962
# Created simple app for stream 963
# Created simple app for stream 964
# Created simple app for stream 965
# Created simple app for stream 966
# Created simple app for stream 967
# Created simple app for stream 968
# Created simple app for stream 969
# Created simple app for stream 970
# Created simple app for stream 971
# Created simple app for stream 972
# Created simple app for stream 973
# Created simple app for stream 974
# Created simple app for stream 975
# Created simple app for stream 976
# Created simple app for stream 977
# Created simple app for stream 978
# Created simple app for stream 979
# Created simple app for stream 980
# Created simple app for stream 981
# Created simple app for stream 982
# Created simple app for stream 983
# Created simple app for stream 984
# Created simple app for stream 985
# Created simple app for stream 986
# Created simple app for stream 987
# Created simple app for stream 988
# Created simple app for stream 989
# Created simple app for stream 990
# Created simple app for stream 991
# Created simple app for stream 992
# Created simple app for stream 993
# Created simple app for stream 994
# Created simple app for stream 995
# Created simple app for stream 996
# Created simple app for stream 997
# Created simple app for stream 998
# Created simple app for stream 999
# Created testcase at: C:\Users\phd\Nextcloud\PhD\Projects\tesla_publish\results\big_testcase_luxi\luxi1000.flex_network_description
# Tasks 2000; Streams 1000; Apps 1000; Average ES utilization 7.601333333333354e-05
# --------------------------------------------------
