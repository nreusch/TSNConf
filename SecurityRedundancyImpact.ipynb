# %%
# Compare: Laxity, BW, CPU, Optimization time 
# Testcases: example, case_study, tiny-medium
# Method: CP
# Run 1: Normal
# Run 2: No redundancy
# Run 3: No security
# Run 4: No redundancy & No security

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import main
from input.input_parameters import InputParameters, EMode, Timeouts
from solution import solution_parser
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
timeouts = Timeouts(600,1800,1800)
k = 20
a = 50000
b = 100000
tc_name = ["TC0_example", "TC2_zhao_case_study",  "tiny3", "small3", "medium3"] 
dfs_results = []

for i in range(len(tc_name)):
    
    path = f"testcases/synthetic4/{tc_name[i]}.flex_network_description"
    
    try:
        no_redundancy = False
        no_security = False
        input_params = InputParameters(EMode.CP_ROUTING_CP_SCHEDULING, timeouts, path, True, "aggregate_impact.csv", 8050, no_redundancy, no_security, False, False, k, a, b)
        solution_object = main.run(input_params)
        df_cp = solution_parser.get_solution_results_info_dataframe(solution_object)
        dfs_results.append(df_cp)
    except Exception:
        pass
    
    try:
        no_redundancy = True
        no_security = False
        input_params = InputParameters(EMode.CP_ROUTING_CP_SCHEDULING, timeouts, path, True, "aggregate_impact.csv", 8050, no_redundancy, no_security, False, False, k, a, b)
        solution_object = main.run(input_params)
        df_cp = solution_parser.get_solution_results_info_dataframe(solution_object)
        dfs_results.append(df_cp)
    except Exception:
        pass
    
    try:
        no_redundancy = False
        no_security = True
        input_params = InputParameters(EMode.CP_ROUTING_CP_SCHEDULING, timeouts, path, True, "aggregate_impact.csv", 8050, no_redundancy, no_security, False, False, k, a, b)
        solution_object = main.run(input_params)
        df_cp = solution_parser.get_solution_results_info_dataframe(solution_object)
        dfs_results.append(df_cp)
    except Exception:
        pass
    
    try:
        no_redundancy = True
        no_security = True
        input_params = InputParameters(EMode.CP_ROUTING_CP_SCHEDULING, timeouts, path, True, "aggregate_impact.csv", 8050, no_redundancy, no_security, False, False, k, a, b)
        solution_object = main.run(input_params)
        df_cp = solution_parser.get_solution_results_info_dataframe(solution_object)
        dfs_results.append(df_cp)
    except Exception:
        pass
# Out:
# --------------------------------------------------------------------------------
# Testcase: TC0_example
# Mode 1: CP Routing, CP Scheduling, Security, Redundancy, Optimization
# Timeout Pint: 600s
# Timeout Routing: 1800s
# Timeout Scheduling: 1800s
# (If combined routing+scheduling, Timeout Scheduling is used)
# No redundancy: False
# No security: False
# Overlap allowed for CP: False
# Infeasible solutions allowed for CP: False
# --------------------------------------------------------------------------------
#
# ---------- 1. Running the chosen mode
# -------------------- Parsed testcase: TC0_example, in 1.14 ms
# -------------------- Found Pint: 500,  in 2.00 ms
# -------------------- Created 2 Security Applications,  in 0.00 ms
# -------------------- Found Routing, in 109.00 ms
# -------------------- Found Schedule in 158.01 ms
# ---------- 2. Serializing the solution
# ...

# %%
pd.concat(dfs_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9b5eb8d7aaa7> in <module>
# ----> 1 pd.concat(dfs_results)
#
# NameError: name 'pd' is not defined
