# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import main
from input.input_parameters import InputParameters, EMode, Timeouts
from solution import solution_parser
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
columns_params=[
            "MTU (Byte)",
            "Frame Overhead (Byte)",
            "MAC Length (Byte)",
            "TESLA Key Length (Byte)",
            "Pint (us)",
            "Hyperperiod (us)",
            "k",
            "a",
            "b",
            "Timeout Routing (s)",
            "Timeout Scheduling (s)"

        ]

columns_result=[
            "Testcase",
            "Method",
            "Total cost",
            "Routing cost",
            "Scheduling cost",
            "Bandwidth use (Mean,%)",
            "CPU use (Mean,%)",
            "Optimization Time (ms)",
            "Total Runtime (ms)",
        ]

# %%
timeouts = Timeouts(600,1800,1800)
k = 10
a = 50000
b = 100000
dfs_results = []
dfs_params = []

# %%
names = ["TC1_automotive", "TC1_automotive_redundant", "TC2_zhao_case_study"]

for n in names:
    path = f"testcases/{n}.flex_network_description"

    try:
        input_params = InputParameters(EMode.CP_ROUTING_CP_SCHEDULING, timeouts, path, True, "aggregate.csv", 8050, False, False, True, True, k, a, b)
        solution_object_cp = main.run(input_params)
        df_cp = solution_parser.get_solution_results_info_dataframe(solution_object_cp)
        df_param = solution_parser.get_solution_parameter_info_dataframe(solution_object_cp)
        dfs_results.append(df_cp)
        dfs_params.append(df_param)
    except Exception:
        pass               

    try:
        input_params = InputParameters(EMode.SA_ROUTING_SA_SCHEDULING_COMB, timeouts, path, True, "aggregate.csv", 8050, False, False, True, True, k, a, b)
        solution_object_sa = main.run(input_params)
        df_sa = solution_parser.get_solution_results_info_dataframe(solution_object_sa)
        df_param = solution_parser.get_solution_parameter_info_dataframe(solution_object_sa)
        dfs_results.append(df_sa)
        dfs_params.append(df_param)
    except Exception:
        pass
# Out:
# --------------------------------------------------------------------------------
# Testcase: TC1_automotive
# Mode 1: CP Routing, CP Scheduling, Security, Redundancy, Optimization
# Timeout Pint: 600s
# Timeout Routing: 1800s
# Timeout Scheduling: 1800s
# (If combined routing+scheduling, Timeout Scheduling is used)
# No redundancy: False
# No security: False
# Overlap allowed for CP: True
# Infeasible solutions allowed for CP: True
# --------------------------------------------------------------------------------
#
# ---------- 1. Running the chosen mode
# -------------------- Parsed testcase: TC1_automotive, in 8.00 ms
# -------------------- Found Pint: 5000,  in 3.00 ms
# -------------------- Created 0 Security Applications,  in 0.00 ms
# -------------------- Found Routing, in 1824237.12 ms
# -------------------- Found Schedule in 1801387.98 ms
# ---------- 2. Serializing the solution
# -------------------- Serialized solution to: testcases\output\TC1_automotive_mode1_600_1800_1800_FFT_0.6,  in 10151.09 ms
# -------------------- Aggregated solution to: aggregate.csv
# ---------- 3. Printing results
# TC1_automotive: 20 ES, 32 SW, 47 Tasks, 25 Streams, 10 Apps, 10520 Cost, 0.07% Bandwidth , 2.73% CPU , 3632526.63ms Optimization Time, Infeasible Apps 0/10, Routing FEASIBLE, Scheduling FEASIBLE
# --------------------------
#
#
# --------------------------------------------------------------------------------
# Testcase: TC1_automotive
# Mode 13: SA Routing+Scheduling, Security, Redundancy, Optimization
# Timeout Pint: 600s
# Timeout Routing: 1800s
# Timeout Scheduling: 1800s
# (If combined routing+scheduling, Timeout Scheduling is used)
# No redundancy: False
# No security: False
# Overlap allowed for CP: True
# Infeasible solutions allowed for CP: True
# --------------------------------------------------------------------------------
#
# ---------- 1. Running the chosen mode
# -------------------- Parsed testcase: TC1_automotive, in 9.00 ms
# -------------------- Found Pint: 5000,  in 2.00 ms
# -------------------- Created 0 Security Applications,  in 0.00 ms
# INITIAL COST: 21265; INFEASIBLE TGA: {}; ROUTING COST: 147
#
# NEW BEST COST: 18715; INFEASIBLE TGA: {}; ROUTING COST: 147
#
# NEW BEST COST: 18545; INFEASIBLE TGA: {}; ROUTING COST: 147
#
# NEW BEST COST: 18145; INFEASIBLE TGA: {}; ROUTING COST: 147
#
# NEW BEST COST: 16985; INFEASIBLE TGA: {}; ROUTING COST: 147
#
# NEW BEST COST: 16957; INFEASIBLE TGA: {}; ROUTING COST: 149
#
# NEW BEST COST: 16937; INFEASIBLE TGA: {}; ROUTING COST: 149
#
# NEW BEST COST: 16737; INFEASIBLE TGA: {}; ROUTING COST: 149
#
# NEW BEST COST: 16537; INFEASIBLE TGA: {}; ROUTING COST: 149
#
# NEW BEST COST: 16333; INFEASIBLE TGA: {}; ROUTING COST: 149
#
# NEW BEST COST: 16320; INFEASIBLE TGA: {}; ROUTING COST: 156
#
# NEW BEST COST: 16319; INFEASIBLE TGA: {}; ROUTING COST: 155
#
# NEW BEST COST: 16031; INFEASIBLE TGA: {}; ROUTING COST: 161
#
# NEW BEST COST: 15733; INFEASIBLE TGA: {}; ROUTING COST: 163
#
# NEW BEST COST: 15263; INFEASIBLE TGA: {}; ROUTING COST: 165
#
# NEW BEST COST: 14943; INFEASIBLE TGA: {}; ROUTING COST: 165
#
# NEW BEST COST: 14924; INFEASIBLE TGA: {}; ROUTING COST: 166
#
# NEW BEST COST: 14922; INFEASIBLE TGA: {}; ROUTING COST: 164
#
# NEW BEST COST: 14662; INFEASIBLE TGA: {}; ROUTING COST: 164
#
# NEW BEST COST: 14661; INFEASIBLE TGA: {}; ROUTING COST: 163
#
# NEW BEST COST: 14603; INFEASIBLE TGA: {}; ROUTING COST: 165
#
# NEW BEST COST: 14104; INFEASIBLE TGA: {}; ROUTING COST: 166
#
# NEW BEST COST: 14101; INFEASIBLE TGA: {}; ROUTING COST: 163
#
# NEW BEST COST: 14100; INFEASIBLE TGA: {}; ROUTING COST: 162
#
# NEW BEST COST: 14063; INFEASIBLE TGA: {}; ROUTING COST: 165
#
# NEW BEST COST: 14062; INFEASIBLE TGA: {}; ROUTING COST: 164
#
# NEW BEST COST: 14061; INFEASIBLE TGA: {}; ROUTING COST: 163
#
# NEW BEST COST: 14060; INFEASIBLE TGA: {}; ROUTING COST: 162
#
# NEW BEST COST: 14059; INFEASIBLE TGA: {}; ROUTING COST: 161
#
# NEW BEST COST: 14058; INFEASIBLE TGA: {}; ROUTING COST: 160
#
# NEW BEST COST: 14057; INFEASIBLE TGA: {}; ROUTING COST: 159
#
# NEW BEST COST: 14055; INFEASIBLE TGA: {}; ROUTING COST: 157
#
# NEW BEST COST: 14054; INFEASIBLE TGA: {}; ROUTING COST: 156
#
# NEW BEST COST: 14053; INFEASIBLE TGA: {}; ROUTING COST: 155
#
# NEW BEST COST: 13603; INFEASIBLE TGA: {}; ROUTING COST: 155
#
# NEW BEST COST: 13602; INFEASIBLE TGA: {}; ROUTING COST: 154
#
# NEW BEST COST: 13601; INFEASIBLE TGA: {}; ROUTING COST: 153
#
# NEW BEST COST: 13600; INFEASIBLE TGA: {}; ROUTING COST: 152
#
# NEW BEST COST: 13599; INFEASIBLE TGA: {}; ROUTING COST: 151
#
# NEW BEST COST: 13598; INFEASIBLE TGA: {}; ROUTING COST: 150
#
# NEW BEST COST: 13597; INFEASIBLE TGA: {}; ROUTING COST: 149
#
# -------------------- Found Schedule in 1800929.38 ms
# ---------- 2. Serializing the solution
# -------------------- Serialized solution to: testcases\output\TC1_automotive_mode13_600_1800_1800_FFT_0.6,  in 4784.61 ms
# -------------------- Aggregated solution to: aggregate.csv
# ---------- 3. Printing results
# TC1_automotive: 20 ES, 32 SW, 47 Tasks, 25 Streams, 10 Apps, 13597 Cost, 0.07% Bandwidth , 2.73% CPU , 1800985.38ms Optimization Time, Infeasible Apps 0/10, Routing NOT_OPTIMIZED, Scheduling INFEASIBLE
# --------------------------
#
#
# --------------------------------------------------------------------------------
# Testcase: TC1_automotive_redundant
# Mode 1: CP Routing, CP Scheduling, Security, Redundancy, Optimization
# Timeout Pint: 600s
# Timeout Routing: 1800s
# Timeout Scheduling: 1800s
# (If combined routing+scheduling, Timeout Scheduling is used)
# No redundancy: False
# No security: False
# Overlap allowed for CP: True
# Infeasible solutions allowed for CP: True
# --------------------------------------------------------------------------------
#
# ---------- 1. Running the chosen mode
# -------------------- Parsed testcase: TC1_automotive_redundant, in 7.00 ms
# -------------------- Found Pint: 5000,  in 2.00 ms
# -------------------- Created 9 Security Applications,  in 0.00 ms
# -------------------- Found Routing, in 1859706.86 ms
# -------------------- Found Schedule in 1804449.26 ms
# ---------- 2. Serializing the solution
# -------------------- Serialized solution to: testcases\output\TC1_automotive_redundant_mode1_600_1800_1800_FFT_0.6,  in 20708.93 ms
# -------------------- Aggregated solution to: aggregate.csv
# ---------- 3. Printing results
# TC1_automotive_redundant: 20 ES, 32 SW, 74 Tasks, 84 Streams, 19 Apps, 2831119 Cost, 0.10% Bandwidth , 3.08% CPU , 3685238.69ms Optimization Time, Infeasible Apps 0/19, Routing FEASIBLE, Scheduling FEASIBLE
# --------------------------
#
#
# --------------------------------------------------------------------------------
# Testcase: TC1_automotive_redundant
# Mode 13: SA Routing+Scheduling, Security, Redundancy, Optimization
# Timeout Pint: 600s
# Timeout Routing: 1800s
# Timeout Scheduling: 1800s
# (If combined routing+scheduling, Timeout Scheduling is used)
# No redundancy: False
# No security: False
# Overlap allowed for CP: True
# Infeasible solutions allowed for CP: True
# --------------------------------------------------------------------------------
#
# ---------- 1. Running the chosen mode
# -------------------- Parsed testcase: TC1_automotive_redundant, in 19.00 ms
# -------------------- Found Pint: 5000,  in 2.00 ms
# -------------------- Created 9 Security Applications,  in 0.00 ms
# INITIAL COST: 13041721; INFEASIBLE TGA: {}; ROUTING COST: 13000388
#
# NEW BEST COST: 12841673; INFEASIBLE TGA: {}; ROUTING COST: 12800390
#
# NEW BEST COST: 12641673; INFEASIBLE TGA: {}; ROUTING COST: 12600390
#
# NEW BEST COST: 12441673; INFEASIBLE TGA: {}; ROUTING COST: 12400390
#
# NEW BEST COST: 12441385; INFEASIBLE TGA: {}; ROUTING COST: 12400390
#
# NEW BEST COST: 12441265; INFEASIBLE TGA: {}; ROUTING COST: 12400392
#
# NEW BEST COST: 12440983; INFEASIBLE TGA: {}; ROUTING COST: 12400394
#
# NEW BEST COST: 12140985; INFEASIBLE TGA: {}; ROUTING COST: 12100396
#
# NEW BEST COST: 11840987; INFEASIBLE TGA: {}; ROUTING COST: 11800398
#
# NEW BEST COST: 11740987; INFEASIBLE TGA: {}; ROUTING COST: 11700398
#
# NEW BEST COST: 11640948; INFEASIBLE TGA: {}; ROUTING COST: 11600399
#
# NEW BEST COST: 11640826; INFEASIBLE TGA: {}; ROUTING COST: 11600399
#
# NEW BEST COST: 11540828; INFEASIBLE TGA: {}; ROUTING COST: 11500401
#
# NEW BEST COST: 11539828; INFEASIBLE TGA: {}; ROUTING COST: 11500401
#
# NEW BEST COST: 11339828; INFEASIBLE TGA: {}; ROUTING COST: 11300401
#
# NEW BEST COST: 11139828; INFEASIBLE TGA: {}; ROUTING COST: 11100401
# NEW BEST COST: 11039817; INFEASIBLE TGA: {}; ROUTING COST: 11000404
#
# NEW BEST COST: 10939819; INFEASIBLE TGA: {}; ROUTING COST: 10900406
#
# NEW BEST COST: 10839821; INFEASIBLE TGA: {}; ROUTING COST: 10800408
#
# NEW BEST COST: 10639821; INFEASIBLE TGA: {}; ROUTING COST: 10600408
#
# NEW BEST COST: 10439822; INFEASIBLE TGA: {}; ROUTING COST: 10400409
#
# NEW BEST COST: 10439807; INFEASIBLE TGA: {}; ROUTING COST: 10400412
#
# NEW BEST COST: 10439791; INFEASIBLE TGA: {}; ROUTING COST: 10400412
#
# NEW BEST COST: 10239791; INFEASIBLE TGA: {}; ROUTING COST: 10200412
#
# NEW BEST COST: 10139792; INFEASIBLE TGA: {}; ROUTING COST: 10100413
#
# NEW BEST COST: 9739792; INFEASIBLE TGA: {}; ROUTING COST: 9700413
#
# NEW BEST COST: 9639862; INFEASIBLE TGA: {}; ROUTING COST: 9600413
#
# NEW BEST COST: 9539864; INFEASIBLE TGA: {}; ROUTING COST: 9500415
#
# NEW BEST COST: 9439867; INFEASIBLE TGA: {}; ROUTING COST: 9400418
#
# NEW BEST COST: 9239875; INFEASIBLE TGA: {}; ROUTING COST: 9200420
#
# NEW BEST COST: 9239805; INFEASIBLE TGA: {}; ROUTING COST: 9200420
#
# NEW BEST COST: 9039805; INFEASIBLE TGA: {}; ROUTING COST: 9000420
#
# NEW BEST COST: 8839805; INFEASIBLE TGA: {}; ROUTING COST: 8800420
#
# NEW BEST COST: 8739807; INFEASIBLE TGA: {}; ROUTING COST: 8700422
#
# NEW BEST COST: 8639807; INFEASIBLE TGA: {}; ROUTING COST: 8600422
#
# NEW BEST COST: 8539808; INFEASIBLE TGA: {}; ROUTING COST: 8500423
#
# NEW BEST COST: 8439808; INFEASIBLE TGA: {}; ROUTING COST: 8400423
#
# NEW BEST COST: 8339808; INFEASIBLE TGA: {}; ROUTING COST: 8300423
#
# NEW BEST COST: 8139808; INFEASIBLE TGA: {}; ROUTING COST: 8100423
#
# NEW BEST COST: 8139807; INFEASIBLE TGA: {}; ROUTING COST: 8100422
#
# NEW BEST COST: 8039809; INFEASIBLE TGA: {}; ROUTING COST: 8000424
#
# NEW BEST COST: 7839809; INFEASIBLE TGA: {}; ROUTING COST: 7800424
#
# NEW BEST COST: 7639828; INFEASIBLE TGA: {}; ROUTING COST: 7600423
#
# NEW BEST COST: 7639826; INFEASIBLE TGA: {}; ROUTING COST: 7600421
#
# NEW BEST COST: 7539844; INFEASIBLE TGA: {}; ROUTING COST: 7500422
#
# NEW BEST COST: 7539824; INFEASIBLE TGA: {}; ROUTING COST: 7500422
#
# NEW BEST COST: 7339824; INFEASIBLE TGA: {}; ROUTING COST: 7300422
#
# NEW BEST COST: 7039822; INFEASIBLE TGA: {}; ROUTING COST: 7000422
#
# NEW BEST COST: 6939822; INFEASIBLE TGA: {}; ROUTING COST: 6900422
#
# NEW BEST COST: 6939617; INFEASIBLE TGA: {}; ROUTING COST: 6900422
#
# NEW BEST COST: 6639614; INFEASIBLE TGA: {}; ROUTING COST: 6600419
#
# NEW BEST COST: 6439614; INFEASIBLE TGA: {}; ROUTING COST: 6400419
#
# NEW BEST COST: 6239614; INFEASIBLE TGA: {}; ROUTING COST: 6200419
#
# NEW BEST COST: 6139616; INFEASIBLE TGA: {}; ROUTING COST: 6100421
#
# NEW BEST COST: 6139424; INFEASIBLE TGA: {}; ROUTING COST: 6100421
#
# NEW BEST COST: 6139404; INFEASIBLE TGA: {}; ROUTING COST: 6100421
#
# NEW BEST COST: 5739392; INFEASIBLE TGA: {}; ROUTING COST: 5700421
#
# NEW BEST COST: 5639373; INFEASIBLE TGA: {}; ROUTING COST: 5600420
#
# NEW BEST COST: 5439373; INFEASIBLE TGA: {}; ROUTING COST: 5400420
#
# NEW BEST COST: 5139373; INFEASIBLE TGA: {}; ROUTING COST: 5100420
#
# NEW BEST COST: 4939373; INFEASIBLE TGA: {}; ROUTING COST: 4900420
#
# NEW BEST COST: 4839373; INFEASIBLE TGA: {}; ROUTING COST: 4800420
#
# NEW BEST COST: 4639722; INFEASIBLE TGA: {}; ROUTING COST: 4600420
#
# NEW BEST COST: 4439720; INFEASIBLE TGA: {}; ROUTING COST: 4400418
#
# NEW BEST COST: 4339711; INFEASIBLE TGA: {}; ROUTING COST: 4300421
#
# NEW BEST COST: 4139711; INFEASIBLE TGA: {}; ROUTING COST: 4100421
#
# -------------------- Found Schedule in 1804929.47 ms
# ---------- 2. Serializing the solution
# -------------------- Serialized solution to: testcases\output\TC1_automotive_redundant_mode13_600_1800_1800_FFT_0.6,  in 15201.73 ms
# -------------------- Aggregated solution to: aggregate.csv
# ---------- 3. Printing results
# TC1_automotive_redundant: 20 ES, 32 SW, 74 Tasks, 84 Streams, 19 Apps, 4139671 Cost, 0.11% Bandwidth , 3.08% CPU , 1805020.47ms Optimization Time, Infeasible Apps 0/19, Routing NOT_OPTIMIZED, Scheduling INFEASIBLE
# --------------------------
#
#
# --------------------------------------------------------------------------------
# Testcase: TC2_zhao_case_study
# Mode 1: CP Routing, CP Scheduling, Security, Redundancy, Optimization
# Timeout Pint: 600s
# Timeout Routing: 1800s
# Timeout Scheduling: 1800s
# (If combined routing+scheduling, Timeout Scheduling is used)
# No redundancy: False
# No security: False
# Overlap allowed for CP: True
# Infeasible solutions allowed for CP: True
# --------------------------------------------------------------------------------
#
# ---------- 1. Running the chosen mode
# -------------------- Parsed testcase: TC2_zhao_case_study, in 8.00 ms
# -------------------- Found Pint: 1000,  in 3.00 ms
# -------------------- Created 2 Security Applications,  in 0.00 ms
# -------------------- Found Routing, in 514.01 ms
# -------------------- Found Schedule in 128973.09 ms
# ---------- 2. Serializing the solution
# -------------------- Serialized solution to: testcases\output\TC2_zhao_case_study_mode1_600_1800_1800_FFT_0.6,  in 1983.00 ms
# -------------------- Aggregated solution to: aggregate.csv
# ---------- 3. Printing results
# TC2_zhao_case_study: 6 ES, 2 SW, 28 Tasks, 29 Streams, 5 Apps, 3771 Cost, 1.47% Bandwidth , 19.30% CPU , 129865.14ms Optimization Time, Infeasible Apps 0/5, Routing OPTIMAL, Scheduling OPTIMAL
# --------------------------
#
#
# --------------------------------------------------------------------------------
# Testcase: TC2_zhao_case_study
# Mode 13: SA Routing+Scheduling, Security, Redundancy, Optimization
# Timeout Pint: 600s
# Timeout Routing: 1800s
# Timeout Scheduling: 1800s
# (If combined routing+scheduling, Timeout Scheduling is used)
# No redundancy: False
# No security: False
# Overlap allowed for CP: True
# Infeasible solutions allowed for CP: True
# --------------------------------------------------------------------------------
#
# ---------- 1. Running the chosen mode
# -------------------- Parsed testcase: TC2_zhao_case_study, in 3.99 ms
# -------------------- Found Pint: 1000,  in 1.00 ms
# -------------------- Created 2 Security Applications,  in 0.00 ms
# INITIAL COST: 706309; INFEASIBLE TGA: {}; ROUTING COST: 700030
#
# NEW BEST COST: 506309; INFEASIBLE TGA: {}; ROUTING COST: 500030
#
# NEW BEST COST: 306309; INFEASIBLE TGA: {}; ROUTING COST: 300030
#
# NEW BEST COST: 306232; INFEASIBLE TGA: {}; ROUTING COST: 300030
#
# NEW BEST COST: 206233; INFEASIBLE TGA: {}; ROUTING COST: 200031
#
# NEW BEST COST: 6232; INFEASIBLE TGA: {}; ROUTING COST: 30
#
# -------------------- Found Schedule in 1800105.23 ms
# ---------- 2. Serializing the solution
# -------------------- Serialized solution to: testcases\output\TC2_zhao_case_study_mode13_600_1800_1800_FFT_0.6,  in 1385.15 ms
# -------------------- Aggregated solution to: aggregate.csv
# ---------- 3. Printing results
# TC2_zhao_case_study: 6 ES, 2 SW, 28 Tasks, 29 Streams, 5 Apps, 5960 Cost, 1.47% Bandwidth , 19.30% CPU , 1800108.23ms Optimization Time, Infeasible Apps 0/5, Routing NOT_OPTIMIZED, Scheduling INFEASIBLE
# --------------------------

# %%
names = ["TC0_example"]
timeouts = Timeouts(600,60,60)
k = 10
a = 50000
b = 100000
dfs_results = []
dfs_params = []

for n in names:
    path = f"testcases/{n}.flex_network_description"

    try:
        input_params = InputParameters(EMode.CP_ROUTING_CP_SCHEDULING, timeouts, path, True, "aggregate.csv", 8050, False, False, True, True, k, a, b)
        solution_object_cp = main.run(input_params)
        df_cp = solution_parser.get_solution_results_info_dataframe(solution_object_cp)
        df_param = solution_parser.get_solution_parameter_info_dataframe(solution_object_cp)
        dfs_results.append(df_cp)
        dfs_params.append(df_param)
    except Exception:
        pass               

    try:
        input_params = InputParameters(EMode.SA_ROUTING_SA_SCHEDULING_COMB, timeouts, path, True, "aggregate.csv", 8050, False, False, True, True, k, a, b)
        solution_object_sa = main.run(input_params)
        df_sa = solution_parser.get_solution_results_info_dataframe(solution_object_sa)
        df_param = solution_parser.get_solution_parameter_info_dataframe(solution_object_sa)
        dfs_results.append(df_sa)
        dfs_params.append(df_param)
    except Exception:
        pass
# Out:
# --------------------------------------------------------------------------------
# Testcase: TC0_example
# Mode 1: CP Routing, CP Scheduling, Security, Redundancy, Optimization
# Timeout Pint: 600s
# Timeout Routing: 60s
# Timeout Scheduling: 60s
# (If combined routing+scheduling, Timeout Scheduling is used)
# No redundancy: False
# No security: False
# Overlap allowed for CP: True
# Infeasible solutions allowed for CP: True
# --------------------------------------------------------------------------------
#
# ---------- 1. Running the chosen mode
# -------------------- Parsed testcase: TC0_example, in 1.11 ms
# -------------------- Found Pint: 500,  in 1.00 ms
# -------------------- Created 2 Security Applications,  in 0.00 ms
# -------------------- Found Routing, in 211.00 ms
# -------------------- Found Schedule in 427.00 ms
# ---------- 2. Serializing the solution
# -------------------- Serialized solution to: testcases\output\TC0_example_mode1_600_60_60_FFT_0.6,  in 744.00 ms
# -------------------- Aggregated solution to: aggregate.csv
# ---------- 3. Printing results
# TC0_example: 4 ES, 2 SW, 9 Tasks, 6 Streams, 3 Apps, 467 Cost, 2.46% Bandwidth , 14.00% CPU , 850.00ms Optimization Time, Infeasible Apps 0/3, Routing OPTIMAL, Scheduling OPTIMAL
# --------------------------
#
#
# --------------------------------------------------------------------------------
# Testcase: TC0_example
# Mode 13: SA Routing+Scheduling, Security, Redundancy, Optimization
# Timeout Pint: 600s
# Timeout Routing: 60s
# Timeout Scheduling: 60s
# (If combined routing+scheduling, Timeout Scheduling is used)
# No redundancy: False
# No security: False
# Overlap allowed for CP: True
# Infeasible solutions allowed for CP: True
# --------------------------------------------------------------------------------
#
# ---------- 1. Running the chosen mode
# -------------------- Parsed testcase: TC0_example, in 1.00 ms
# -------------------- Found Pint: 500,  in 1.00 ms
# -------------------- Created 2 Security Applications,  in 0.00 ms
# INITIAL COST: 600521; INFEASIBLE TGA: {}; ROUTING COST: 600016
#
# NEW BEST COST: 500522; INFEASIBLE TGA: {}; ROUTING COST: 500017
#
# NEW BEST COST: 400479; INFEASIBLE TGA: {}; ROUTING COST: 400018
#
# NEW BEST COST: 200478; INFEASIBLE TGA: {}; ROUTING COST: 200017
#
# NEW BEST COST: 477; INFEASIBLE TGA: {}; ROUTING COST: 16
#
# -------------------- Found Schedule in 60038.49 ms
# ---------- 2. Serializing the solution
# -------------------- Serialized solution to: testcases\output\TC0_example_mode13_600_60_60_FFT_0.6,  in 708.35 ms
# -------------------- Aggregated solution to: aggregate.csv
# ---------- 3. Printing results
# TC0_example: 4 ES, 2 SW, 9 Tasks, 6 Streams, 3 Apps, 477 Cost, 2.46% Bandwidth , 14.00% CPU , 60039.49ms Optimization Time, Infeasible Apps 0/3, Routing NOT_OPTIMIZED, Scheduling INFEASIBLE
# --------------------------
